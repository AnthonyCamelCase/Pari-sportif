# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import numpy as np
from bokeh.plotting import figure, show,output_notebook
from bokeh.models import ColumnDataSource, HoverTool, LabelSet
from bokeh.models.widgets import Panel, Tabs
pd.set_option('max_columns', 40)

df = pd.read_csv("data_clean_feature_player.csv",index_col=0)

# %%
df
# Out:
#        ATP   Location                          Tournament        Date  \
# 0        1   Adelaide  Australian Hardcourt Championships  2000-01-03
# 1        3       Doha                          Qatar Open  2000-01-03
# 2        3       Doha                          Qatar Open  2000-01-03
# 3        3       Doha                          Qatar Open  2000-01-03
# 4        3       Doha                          Qatar Open  2000-01-03
# ...    ...        ...                                 ...         ...
# 44703   17     Dubai           Dubai Tennis Championships  2018-03-03
# 44704   16   Acapulco                    Abierto Mexicano  2018-03-03
# 44705   18  Sao Paulo                         Brasil Open  2018-03-03
# 44706   16   Acapulco                    Abierto Mexicano  2018-03-04
# 44707   18  Sao Paulo                         Brasil Open  2018-03-04
#
#               Series    Court Surface       Round  Best of            Winner  \
# ...

# %%
df.Comment.unique()
# Out:
# array(['Completed', 'Retired', 'Walkover', 'Disqualified'], dtype=object)

# %%
match_non_fini = df[(df.Comment == 'Retired')| (df.Comment == "Walkover") | (df.Comment == "Disqualified")].index

# %%
df = df.drop(match_non_fini)
df.index = range(len(df.index))

# %%
df =df.dropna()

# %%
df =df.drop(["ATP","Location","Tournament","Date","Series","Court","Surface","Wsets","Lsets","Comment"],axis=1)

# %%
df
# Out:
#             Round  Best of            Winner               Loser  WRank  \
# 8365    1st Round        3       Ulihrach B.           Kiefer N.    246
# 8366    1st Round        3        Youzhny M.       Schuettler R.     43
# 8367    1st Round        3       Sargsian S.           Carraz G.     39
# 8371    1st Round        3          Arazi H.          Enqvist T.     52
# 8373    1st Round        3        Andreev I.  Ramirez-Hidalgo R.     88
# ...           ...      ...               ...                 ...    ...
# 43010   The Final        3  Bautista Agut R.          Pouille L.     23
# 43011  Semifinals        3       Anderson K.        Donaldson J.      8
# 43012  Semifinals        3          Jarry N.         Zeballos H.     73
# 43013   The Final        3    Del Potro J.M.         Anderson K.      9
# 43014   The Final        3        Fognini F.            Jarry N.     20
#
#        LRank    PSW    PSL  B365W  B365L   elo_winner    elo_loser  proba_elo  \
# ...
